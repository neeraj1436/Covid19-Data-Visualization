# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
corona_dataset=pd.read_excel("C:/users/user/corona.xlsx")
print(corona_dataset.columns)
# Out:
# Index(['Patient Number', 'State Patient Number', 'Date Announced',
#        'Age Bracket', 'Gender', 'Detected City', 'Detected District',
#        'Detected State', 'Current Status', 'Notes',
#        'Contracted from which Patient (Suspected)', 'Nationality',
#        'Type of transmission', 'Status Change Date', 'Source_1', 'Source_2',
#        'Source_3', 'Backup Notes'],
#       dtype='object')

# %%
state=corona_dataset["Detected State"].value_counts()
state.plot.barh(figsize=(10,10),title="NUMBER OF CASES IN STATE")
plt.savefig("Cases in State.png",dpi=960)
plt.show()

# %%
c=['red','green','blue','yellow','pink','orange','cyan','olive', 'gray']
NRI_in_state=corona_dataset.groupby(["Detected State","Nationality"])["Nationality"].count()
NRI_in_state.unstack().plot.barh(figsize=[15,15],stacked=True,color=c)
plt.savefig("NRI IN STATES,NIS.png",dpi=960)
plt.show()

# %%
a=corona_dataset["Current Status"]
a.unique()
# Out:
# array(['Recovered', 'Hospitalized', 'Deceased', 'Migrated'], dtype=object)

# %%
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize
URL = "https://api.covid19india.org/raw_data.json" 
d = requests.get(url=URL).json()
g=pd.DataFrame(data["raw_data"])
female=g[g["gender"]=="F"]
male=g[g["gender"]=="M"]
female=female['patientnumber'].count()
male=male['patientnumber'].count()
y=[male,female]
x=['Male','Female']
plt.bar(x,y,color=["red"])
plt.show()

# %%
import datetime
a= pd.to_datetime(corona_dataset["Date Announced"])
a
b=1
c=2
d=1614
e=[b,c,d]
Month=['January', 'Feburary', 'March']
plt.plot(Month,e)
plt.ylabel('Cases of Covid19')
# Out:
# Text(0, 0.5, 'Cases of Covid19')

# %%
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize
URL = "https://api.covid19india.org/raw_data.json" 
data = requests.get(url=URL).json()
URL = "https://api.covid19india.org/raw_data.json" 
d = requests.get(url=URL).json()
covid19=pd.DataFrame(data["raw_data"])
def barplt(g1,g2):
    male= covid19[covid19['gender'=='M']]
    female= covid19[covid19['gender'=='F']]
    if(g1=='M'):
        
        c1=male["currentstatus"=="Hospitalized"].count()
        a1=male['currentstatus'=="Recovered"].count()
        d1=male['currentstatus'=="Migrated"].count()
        r1=male["currentstatus"=="deceased"].count()
    if(g2=='F'):
        c2=female["currentstatus"=="Hospitalized"].count()
        a2=female['currentstatus'=="Recovered"].count()
        d2=female['currentstatus'=="Migrated"].count()
        r2=female["currentstatus"=="deceased"].count()
    x1=[c1,a1,d1,r1]
    x2=[c2,a2,d2,r2]
    y=['Hospitalized','recovered','Migrated','deceased','state' ]
    xpos=np.arange(len(y))
    plt.bar(xpos-0.2,x1,width=0.4,label=st1)
    plt.bar(xpos+0.2,x2,width=0.4,label=st2)
    plt.xlabel("Category")
    plt.ylabel("No. of cases")
    plt.title(st1+" and "+st2)
    plt.xticks(xpos,y)
    plt.legend()
    plt.show()
stn1=input("enter g1")
stn2=input("enter g2")
barplt(stn1.capitalize(),stn2.capitalize())
# Out:
# enter g1M
# enter g2F
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-c45fcb746040> in <module>
# ...
